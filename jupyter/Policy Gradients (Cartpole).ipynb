# %%
import os, sys
import warnings
import random
import time

import gym

import numpy as np
from skimage import transform, util, color
from collections import deque
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
env.seed(1)
# Out:
# [1]

# %%
## ENVIRONMENT Hyperparameters
state_size = 4
action_size = env.action_space.n

## TRAINING Hyperparameters
max_episodes = 10000
learning_rate = 0.01
gamma = 0.95 # Discount rate

# %%
def discount_and_normalize(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)
    cumulative = 0.0
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)
    
    return discounted_episode_rewards

# %%
class PGN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(4, 10)
        self.fc2 = nn.Linear(10, 2)
        self.fc3 = nn.Linear(2, 2)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        x = F.log_softmax(x, dim=-1)
        return x

class NNet():
    def __init__(self):
        self.nnet = PGN().cuda()
        
    def train(self, states, actions, discounted_episode_rewards):
        optimizer = optim.Adam(self.nnet.parameters(), lr=learning_rate)
        self.nnet.train()
        states = torch.FloatTensor(states).contiguous().cuda()
        actions = torch.LongTensor(actions).contiguous().cuda()
        discounted_episode_rewards = torch.FloatTensor(discounted_episode_rewards).contiguous().cuda()
        
        states, actions = Variable(states), Variable(actions) ### !!! I WAS BREAKING THE COMPTUATION GRAPH
        pred = torch.exp(self.nnet(states)) ### DON'T WRAP PREDICTIONS IN A VARIABLE
#       #Variable(torch.max(actions.long(), 1)[1]),

        loss = self.loss(pred, actions, discounted_episode_rewards)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
#         a = list(self.nnet.parameters())[0].clone()
#         loss.backward()
#         optimizer.step()
#         b = list(self.nnet.parameters())[0].clone()
#         print(list(self.nnet.parameters())[0].grad)
        return loss
        
    def predict(self, state):
        state = torch.FloatTensor(state).contiguous().cuda()
        with torch.no_grad():
            state = Variable(state)
        self.nnet.eval()
        x = self.nnet(state)
        return torch.exp(x).data.cpu().numpy()
    
    def loss(self, pred, actions, discounted_episode_rewards):
        loss = F.cross_entropy(pred, actions, reduce=False)
        mean_loss = torch.mean(loss*discounted_episode_rewards)
        return mean_loss
'''
    def loss(self, states, actions, discounted_episode_rewards):
        neg_log_probs = F.cross_entropy(states, actions)
        return torch.mean(neg_log_probs * discounted_episode_rewards)
'''
# Out:
# '\n    def loss(self, states, actions, discounted_episode_rewards):\n        neg_log_probs = F.cross_entropy(states, actions)\n        return torch.mean(neg_log_probs * discounted_episode_rewards)\n'

# %%
nnet = NNet()

# %%
allRewards = []
total_rewards = 0
maximumRewardRecorded = 0
loss = 0
episode_states, episode_actions, episode_rewards = [],[],[]

for episode in range(max_episodes):
    episode_rewards_sum = 0
    state = env.reset()
    env.render()
    
    while True:
        pi = nnet.predict(state.reshape([1,4]))
#         print(pi)
        action = np.random.choice(range(pi.shape[1]), p=pi.ravel())
        new_state, reward, done, info = env.step(action)
        
        episode_states.append(state)
#         actions_ = np.zeros(action_size)
#         actions_[action] = 1
        episode_actions.append(action)
        episode_rewards.append(reward)
        if done:
            episode_rewards_sum = np.sum(episode_rewards)
            allRewards.append(episode_rewards_sum)
            total_rewards = np.sum(allRewards)
            mean_reward = np.divide(total_rewards, episode+1)
            maximumRewardRecorded = np.amax(allRewards)
            
            print("==========================================")
            print("Episode: ", episode)
            print(f"Loss: {loss}")
            print("Reward: ", episode_rewards_sum)
            print("Mean Reward", mean_reward)
            print("Max reward so far: ", maximumRewardRecorded)
            ###
#             print(np.vstack(np.array(episode_states)).shape)
#             print(np.vstack(np.array(episode_actions)).shape)
#             print(np.array(episode_actions).shape)
            discounted_episode_rewards = discount_and_normalize(episode_rewards)

            loss = nnet.train(np.vstack(np.array(episode_states)), np.array(episode_actions), discounted_episode_rewards)
            episode_states, episode_actions, episode_rewards = [],[],[]
            
            break
        state = new_state
# Out:
# ==========================================
# Episode:  0
# Loss: 0
# Reward:  22.0
# Mean Reward 22.0
# Max reward so far:  22.0
# ==========================================
# Episode:  1
# Loss: 0.01358126476407051
# Reward:  25.0
# Mean Reward 23.5
# Max reward so far:  25.0
# ==========================================
# Episode:  2
# Loss: -0.002757689915597439
# Reward:  10.0
# Mean Reward 19.0
# Max reward so far:  25.0
# ==========================================
# Episode:  3
# Loss: 0.022729426622390747
# Reward:  11.0
# Mean Reward 17.0
# Max reward so far:  25.0
# ==========================================
# Episode:  4
# Loss: -0.0614120252430439
# Reward:  13.0
# Mean Reward 16.2
# Max reward so far:  25.0
# ==========================================
# Episode:  5
# Loss: 0.04941382631659508
# Reward:  12.0
# Mean Reward 15.5
# Max reward so far:  25.0
# ==========================================
# Episode:  6
# Loss: -0.02353670634329319
# Reward:  20.0
# Mean Reward 16.142857142857142
# Max reward so far:  25.0
# ==========================================
# Episode:  7
# Loss: 0.006193923763930798
# Reward:  10.0
# Mean Reward 15.375
# Max reward so far:  25.0
# ==========================================
# Episode:  8
# Loss: -0.05598437786102295
# Reward:  10.0
# Mean Reward 14.777777777777779
# Max reward so far:  25.0
# ==========================================
# Episode:  9
# Loss: -0.001620602561160922
# Reward:  12.0
# Mean Reward 14.5
# Max reward so far:  25.0
# ==========================================
# Episode:  10
# Loss: 0.047970160841941833
# Reward:  17.0
# Mean Reward 14.727272727272727
# Max reward so far:  25.0
# ==========================================
# Episode:  11
# Loss: -0.004214314743876457
# Reward:  15.0
# Mean Reward 14.75
# Max reward so far:  25.0
# ==========================================
# Episode:  12
# Loss: 0.07333257794380188
# Reward:  13.0
# Mean Reward 14.615384615384615
# Max reward so far:  25.0
# ==========================================
# Episode:  13
# Loss: -0.03788744658231735
# Reward:  19.0
# Mean Reward 14.928571428571429
# Max reward so far:  25.0
# ==========================================
# Episode:  14
# Loss: 0.021296337246894836
# Reward:  11.0
# Mean Reward 14.666666666666666
# Max reward so far:  25.0
# ==========================================
# Episode:  15
# Loss: -0.04265712574124336
# Reward:  8.0
# Mean Reward 14.25
# Max reward so far:  25.0
# ==========================================
# Episode:  16
# Loss: -0.023179806768894196
# Reward:  9.0
# Mean Reward 13.941176470588236
# Max reward so far:  25.0
# ==========================================
# Episode:  17
# Loss: -0.04767872393131256
# Reward:  21.0
# Mean Reward 14.333333333333334
# Max reward so far:  25.0
# ==========================================
# Episode:  18
# Loss: 0.011759825982153416
# Reward:  25.0
# Mean Reward 14.894736842105264
# Max reward so far:  25.0
# ==========================================
# Episode:  19
# Loss: -0.0028667831793427467
# Reward:  12.0
# Mean Reward 14.75
# Max reward so far:  25.0
# ==========================================
# Episode:  20
# Loss: -0.019273480400443077
# Reward:  20.0
# Mean Reward 15.0
# Max reward so far:  25.0
# ==========================================
# Episode:  21
# Loss: -0.010749655775725842
# Reward:  16.0
# Mean Reward 15.045454545454545
# Max reward so far:  25.0
# ==========================================
# Episode:  22
# Loss: -0.007577709853649139
# Reward:  16.0
# Mean Reward 15.08695652173913
# Max reward so far:  25.0
# ==========================================
# Episode:  23
# Loss: -0.011329039931297302
# Reward:  11.0
# Mean Reward 14.916666666666666
# Max reward so far:  25.0
# ==========================================
# Episode:  24
# Loss: -0.024337800219655037
# Reward:  21.0
# Mean Reward 15.16
# Max reward so far:  25.0
# ==========================================
# Episode:  25
# Loss: 0.020830897614359856
# Reward:  10.0
# Mean Reward 14.961538461538462
# Max reward so far:  25.0
# ==========================================
# Episode:  26
# Loss: -0.04631604626774788
# Reward:  28.0
# Mean Reward 15.444444444444445
# Max reward so far:  28.0
# ==========================================
# Episode:  27
# Loss: 0.0036410391330718994
# Reward:  51.0
# Mean Reward 16.714285714285715
# Max reward so far:  51.0
# ==========================================
# Episode:  28
# Loss: 0.005227779503911734
# Reward:  13.0
# Mean Reward 16.586206896551722
# Max reward so far:  51.0
# ==========================================
# Episode:  29
# Loss: -0.017928022891283035
# Reward:  16.0
# Mean Reward 16.566666666666666
# Max reward so far:  51.0
# ==========================================
# Episode:  30
# Loss: -0.01106802374124527
# Reward:  17.0
# Mean Reward 16.580645161290324
# Max reward so far:  51.0
# ==========================================
# Episode:  31
# Loss: 0.050443727523088455
# Reward:  31.0
# Mean Reward 17.03125
# Max reward so far:  51.0
# ==========================================
# Episode:  32
# Loss: 0.00685880659148097
# Reward:  12.0
# Mean Reward 16.87878787878788
# Max reward so far:  51.0
# ==========================================
# Episode:  33
# Loss: -0.019529199227690697
# Reward:  16.0
# Mean Reward 16.852941176470587
# Max reward so far:  51.0
# ==========================================
# Episode:  34
# Loss: -0.023498021066188812
# Reward:  27.0
# Mean Reward 17.142857142857142
# Max reward so far:  51.0
# ==========================================
# Episode:  35
# Loss: -0.0009974020067602396
# Reward:  30.0
# Mean Reward 17.5
# Max reward so far:  51.0
# ==========================================
# Episode:  36
# Loss: 0.002834399463608861
# Reward:  19.0
# Mean Reward 17.54054054054054
# Max reward so far:  51.0
# ==========================================
# Episode:  37
# Loss: 0.0031592720188200474
# Reward:  52.0
# Mean Reward 18.44736842105263
# Max reward so far:  52.0
# ==========================================
# Episode:  38
# Loss: 0.001823658705689013
# Reward:  12.0
# Mean Reward 18.28205128205128
# Max reward so far:  52.0
# ==========================================
# Episode:  39
# Loss: -0.018150707706809044
# Reward:  19.0
# Mean Reward 18.3
# Max reward so far:  52.0
# ==========================================
# Episode:  40
# Loss: 0.02899814024567604
# Reward:  44.0
# Mean Reward 18.926829268292682
# Max reward so far:  52.0
# ==========================================
# Episode:  41
# Loss: -0.004952559247612953
# Reward:  30.0
# Mean Reward 19.19047619047619
# Max reward so far:  52.0
# ==========================================
# Episode:  42
# Loss: 0.017363743856549263
# Reward:  13.0
# Mean Reward 19.046511627906977
# Max reward so far:  52.0
# ==========================================
# Episode:  43
# Loss: -0.017119325697422028
# Reward:  20.0
# Mean Reward 19.068181818181817
# Max reward so far:  52.0
# ==========================================
# Episode:  44
# Loss: 0.024983221665024757
# Reward:  19.0
# Mean Reward 19.066666666666666
# Max reward so far:  52.0
# ==========================================
# Episode:  45
# Loss: -0.022685835137963295
# Reward:  17.0
# Mean Reward 19.02173913043478
# Max reward so far:  52.0
# ==========================================
# Episode:  46
# Loss: 0.0002472681226208806
# Reward:  25.0
# Mean Reward 19.148936170212767
# Max reward so far:  52.0
# ==========================================
# Episode:  47
# Loss: 0.01674690656363964
# Reward:  19.0
# Mean Reward 19.145833333333332
# Max reward so far:  52.0
# ==========================================
# Episode:  48
# Loss: -0.0235604178160429
# Reward:  25.0
# Mean Reward 19.26530612244898
# Max reward so far:  52.0
# ==========================================
# Episode:  49
# Loss: -0.022431746125221252
# Reward:  11.0
# Mean Reward 19.1
# Max reward so far:  52.0
# ==========================================
# Episode:  50
# Loss: -0.003008148865774274
# Reward:  15.0
# Mean Reward 19.019607843137255
# Max reward so far:  52.0
# ==========================================
# Episode:  51
# Loss: -0.024511845782399178
# Reward:  38.0
# Mean Reward 19.384615384615383
# Max reward so far:  52.0
# ==========================================
# Episode:  52
# Loss: 0.017200881615281105
# Reward:  11.0
# Mean Reward 19.22641509433962
# Max reward so far:  52.0
# ==========================================
# Episode:  53
# Loss: -0.03276614099740982
# Reward:  22.0
# Mean Reward 19.27777777777778
# Max reward so far:  52.0
# ==========================================
# Episode:  54
# Loss: -0.004127968568354845
# Reward:  16.0
# Mean Reward 19.21818181818182
# Max reward so far:  52.0
# ==========================================
# Episode:  55
# Loss: 0.04504259303212166
# Reward:  9.0
# Mean Reward 19.035714285714285
# Max reward so far:  52.0
# ==========================================
# Episode:  56
# Loss: 0.10142400860786438
# Reward:  20.0
# Mean Reward 19.05263157894737
# Max reward so far:  52.0
# ==========================================
# Episode:  57
# Loss: -0.003317707683891058
# Reward:  22.0
# Mean Reward 19.103448275862068
# Max reward so far:  52.0
# ==========================================
# Episode:  58
# Loss: -0.004958071280270815
# Reward:  68.0
# Mean Reward 19.93220338983051
# Max reward so far:  68.0
# ==========================================
# Episode:  59
# Loss: -0.009539627470076084
# Reward:  8.0
# Mean Reward 19.733333333333334
# Max reward so far:  68.0
# ==========================================
# Episode:  60
# Loss: -0.022858411073684692
# Reward:  27.0
# Mean Reward 19.852459016393443
# Max reward so far:  68.0
# ==========================================
# Episode:  61
# Loss: 0.01916121132671833
# Reward:  37.0
# Mean Reward 20.129032258064516
# Max reward so far:  68.0
# ==========================================
# Episode:  62
# Loss: 0.010198920033872128
# Reward:  13.0
# Mean Reward 20.015873015873016
# Max reward so far:  68.0
# ==========================================
# Episode:  63
# Loss: -0.01630672998726368
# Reward:  23.0
# Mean Reward 20.0625
# Max reward so far:  68.0
# ==========================================
# Episode:  64
# Loss: 0.00840594433248043
# Reward:  13.0
# Mean Reward 19.953846153846154
# Max reward so far:  68.0
# ==========================================
# Episode:  65
# Loss: -0.003934025764465332
# Reward:  27.0
# Mean Reward 20.060606060606062
# Max reward so far:  68.0
# ==========================================
# Episode:  66
# Loss: 0.017958054319024086
# Reward:  39.0
# Mean Reward 20.34328358208955
# Max reward so far:  68.0
# ==========================================
# Episode:  67
# Loss: -0.016251975670456886
# Reward:  19.0
# Mean Reward 20.323529411764707
# Max reward so far:  68.0
# ==========================================
# Episode:  68
# Loss: 0.023621289059519768
# Reward:  16.0
# Mean Reward 20.26086956521739
# Max reward so far:  68.0
# ==========================================
# Episode:  69
# Loss: -0.013072647154331207
# Reward:  31.0
# Mean Reward 20.414285714285715
# Max reward so far:  68.0
# ==========================================
# Episode:  70
# Loss: -0.0020121990237385035
# Reward:  52.0
# Mean Reward 20.859154929577464
# Max reward so far:  68.0
# ==========================================
# Episode:  71
# Loss: -0.003280078759416938
# Reward:  25.0
# Mean Reward 20.916666666666668
# Max reward so far:  68.0
# ==========================================
# Episode:  72
# Loss: -0.0007736158440820873
# Reward:  11.0
# Mean Reward 20.78082191780822
# Max reward so far:  68.0
# ==========================================
# Episode:  73
# Loss: 0.07413628697395325
# Reward:  63.0
# Mean Reward 21.35135135135135
# Max reward so far:  68.0
# ==========================================
# Episode:  74
# Loss: -0.018556738272309303
# Reward:  27.0
# Mean Reward 21.426666666666666
# Max reward so far:  68.0
# ==========================================
# Episode:  75
# Loss: -0.018777405843138695
# Reward:  14.0
# Mean Reward 21.32894736842105
# Max reward so far:  68.0
# ==========================================
# Episode:  76
# Loss: 0.0013124176766723394
# Reward:  60.0
# Mean Reward 21.83116883116883
# Max reward so far:  68.0
# ==========================================
# Episode:  77
# Loss: -0.024609215557575226
# Reward:  12.0
# Mean Reward 21.705128205128204
# Max reward so far:  68.0
# ==========================================
# Episode:  78
# Loss: -0.05620180442929268
# Reward:  46.0
# Mean Reward 22.0126582278481
# Max reward so far:  68.0
# ==========================================
# Episode:  79
# Loss: -0.004452683962881565
# Reward:  61.0
# Mean Reward 22.5
# Max reward so far:  68.0
# ==========================================
# Episode:  80
# Loss: -0.017909031361341476
# Reward:  58.0
# Mean Reward 22.938271604938272
# Max reward so far:  68.0
# ==========================================
# Episode:  81
# Loss: -0.014691784046590328
# Reward:  18.0
# Mean Reward 22.878048780487806
# Max reward so far:  68.0
# ==========================================
# Episode:  82
# Loss: -0.001039610942825675
# Reward:  77.0
# Mean Reward 23.53012048192771
# Max reward so far:  77.0
# ==========================================
# Episode:  83
# Loss: -0.00442718667909503
# Reward:  23.0
# Mean Reward 23.523809523809526
# Max reward so far:  77.0
# ==========================================
# Episode:  84
# Loss: 0.02135162241756916
# Reward:  26.0
# Mean Reward 23.55294117647059
# Max reward so far:  77.0
# ==========================================
# Episode:  85
# Loss: -0.0003365094889886677
# Reward:  108.0
# Mean Reward 24.53488372093023
# Max reward so far:  108.0
# ==========================================
# Episode:  86
# Loss: 0.0002076796954497695
# Reward:  22.0
# Mean Reward 24.50574712643678
# Max reward so far:  108.0
# ==========================================
# Episode:  87
# Loss: 0.003189856419339776
# Reward:  22.0
# Mean Reward 24.477272727272727
# Max reward so far:  108.0
# ==========================================
# Episode:  88
# Loss: -0.0032462207600474358
# Reward:  32.0
# Mean Reward 24.56179775280899
# Max reward so far:  108.0
# ==========================================
# Episode:  89
# Loss: -0.026644039899110794
# Reward:  21.0
# Mean Reward 24.522222222222222
# Max reward so far:  108.0
# ==========================================
# Episode:  90
# Loss: -0.014201879501342773
# Reward:  13.0
# Mean Reward 24.395604395604394
# Max reward so far:  108.0
# ==========================================
# Episode:  91
# Loss: 0.023382369428873062
# Reward:  18.0
# Mean Reward 24.32608695652174
# Max reward so far:  108.0
# ==========================================
# Episode:  92
# Loss: 0.005213055294007063
# Reward:  33.0
# Mean Reward 24.419354838709676
# Max reward so far:  108.0
# ==========================================
# Episode:  93
# Loss: -0.024201354011893272
# Reward:  27.0
# Mean Reward 24.4468085106383
# Max reward so far:  108.0
# ==========================================
# Episode:  94
# Loss: -0.00066233123652637
# Reward:  137.0
# Mean Reward 25.63157894736842
# Max reward so far:  137.0
# ==========================================
# Episode:  95
# Loss: -0.009444493800401688
# Reward:  30.0
# Mean Reward 25.677083333333332
# Max reward so far:  137.0
# ==========================================
# Episode:  96
# Loss: -0.041058000177145004
# Reward:  24.0
# Mean Reward 25.65979381443299
# Max reward so far:  137.0
# ==========================================
# Episode:  97
# Loss: 0.0010429570684209466
# Reward:  66.0
# Mean Reward 26.071428571428573
# Max reward so far:  137.0
# ==========================================
# Episode:  98
# Loss: 0.004125432576984167
# Reward:  41.0
# Mean Reward 26.22222222222222
# Max reward so far:  137.0
# ==========================================
# Episode:  99
# Loss: -0.01847776025533676
# Reward:  12.0
# Mean Reward 26.08
# Max reward so far:  137.0
# ==========================================
# Episode:  100
# Loss: -0.020276585593819618
# Reward:  34.0
# Mean Reward 26.15841584158416
# Max reward so far:  137.0
# ==========================================
# Episode:  101
# Loss: -0.033918529748916626
# Reward:  47.0
# Mean Reward 26.362745098039216
# Max reward so far:  137.0
# ==========================================
# Episode:  102
# Loss: -0.004832051694393158
# Reward:  23.0
# Mean Reward 26.33009708737864
# Max reward so far:  137.0
# ==========================================
# Episode:  103
# Loss: 0.03941897675395012
# Reward:  51.0
# Mean Reward 26.567307692307693
# Max reward so far:  137.0
# ==========================================
# Episode:  104
# Loss: 0.0003122992056887597
# Reward:  43.0
# Mean Reward 26.723809523809525
# Max reward so far:  137.0
# ==========================================
# Episode:  105
# Loss: -0.04032020643353462
# Reward:  63.0
# Mean Reward 27.066037735849058
# Max reward so far:  137.0
# ==========================================
# Episode:  106
# Loss: -0.03880808874964714
# Reward:  14.0
# Mean Reward 26.94392523364486
# Max reward so far:  137.0
# ==========================================
# Episode:  107
# Loss: 0.0060811215080320835
# Reward:  37.0
# Mean Reward 27.037037037037038
# Max reward so far:  137.0
# ==========================================
# Episode:  108
# Loss: 0.012005923315882683
# Reward:  32.0
# Mean Reward 27.08256880733945
# Max reward so far:  137.0
# ==========================================
# Episode:  109
# Loss: -0.012985754758119583
# Reward:  28.0
# Mean Reward 27.09090909090909
# Max reward so far:  137.0
# ==========================================
# Episode:  110
# Loss: -0.005316772498190403
# Reward:  36.0
# Mean Reward 27.17117117117117
# Max reward so far:  137.0
# ==========================================
# Episode:  111
# Loss: 0.001970496494323015
# Reward:  61.0
# Mean Reward 27.473214285714285
# Max reward so far:  137.0
# ==========================================
# Episode:  112
# Loss: -0.003201979212462902
# Reward:  52.0
# Mean Reward 27.690265486725664
# Max reward so far:  137.0
# ==========================================
# Episode:  113
# Loss: 0.01903255470097065
# Reward:  91.0
# Mean Reward 28.24561403508772
# Max reward so far:  137.0
# ==========================================
# Episode:  114
# Loss: -0.008772052824497223
# Reward:  43.0
# Mean Reward 28.37391304347826
# Max reward so far:  137.0
# ==========================================
# Episode:  115
# Loss: 0.011818278580904007
# Reward:  32.0
# Mean Reward 28.405172413793103
# Max reward so far:  137.0
# ==========================================
# Episode:  116
# Loss: 0.0010452140122652054
# Reward:  48.0
# Mean Reward 28.572649572649574
# Max reward so far:  137.0
# ==========================================
# Episode:  117
# Loss: -0.006088194902986288
# Reward:  71.0
# Mean Reward 28.93220338983051
# Max reward so far:  137.0
# ==========================================
# Episode:  118
# Loss: 0.006199568044394255
# Reward:  31.0
# Mean Reward 28.949579831932773
# Max reward so far:  137.0
# ==========================================
# Episode:  119
# Loss: 0.011231048963963985
# Reward:  64.0
# Mean Reward 29.241666666666667
# Max reward so far:  137.0
# ==========================================
# Episode:  120
# Loss: -0.019121669232845306
# Reward:  27.0
# Mean Reward 29.223140495867767
# Max reward so far:  137.0
# ==========================================
# Episode:  121
# Loss: 0.00860515795648098
# Reward:  21.0
# Mean Reward 29.15573770491803
# Max reward so far:  137.0
# ==========================================
# Episode:  122
# Loss: -0.002937975339591503
# Reward:  38.0
# Mean Reward 29.227642276422763
# Max reward so far:  137.0
# ==========================================
# Episode:  123
# Loss: 0.0011366746621206403
# Reward:  10.0
# Mean Reward 29.072580645161292
# Max reward so far:  137.0
# ==========================================
# Episode:  124
# Loss: -0.03602597862482071
# Reward:  15.0
# Mean Reward 28.96
# Max reward so far:  137.0
# ==========================================
# Episode:  125
# Loss: 0.039841167628765106
# Reward:  11.0
# Mean Reward 28.817460317460316
# Max reward so far:  137.0
# ==========================================
# Episode:  126
# Loss: -0.0002500360715202987
# Reward:  18.0
# Mean Reward 28.73228346456693
# Max reward so far:  137.0
# ==========================================
# Episode:  127
# Loss: -0.04854712262749672
# Reward:  32.0
# Mean Reward 28.7578125
# Max reward so far:  137.0
# ==========================================
# Episode:  128
# Loss: -0.01985953003168106
# Reward:  44.0
# Mean Reward 28.875968992248062
# Max reward so far:  137.0
# ==========================================
# Episode:  129
# Loss: -0.011318529024720192
# Reward:  11.0
# Mean Reward 28.73846153846154
# Max reward so far:  137.0
# ==========================================
# Episode:  130
# Loss: 0.012910577468574047
# Reward:  51.0
# Mean Reward 28.908396946564885
# Max reward so far:  137.0
# ==========================================
# Episode:  131
# Loss: -0.007481403183192015
# Reward:  46.0
# Mean Reward 29.03787878787879
# Max reward so far:  137.0
# ==========================================
# Episode:  132
# Loss: -0.017684873193502426
# Reward:  55.0
# Mean Reward 29.23308270676692
# Max reward so far:  137.0
# ==========================================
# Episode:  133
# Loss: -0.01969432272017002
# Reward:  20.0
# Mean Reward 29.16417910447761
# Max reward so far:  137.0
# ==========================================
# Episode:  134
# Loss: 0.004730033688247204
# Reward:  80.0
# Mean Reward 29.54074074074074
# Max reward so far:  137.0
# ==========================================
# Episode:  135
# Loss: -0.014884203672409058
# Reward:  63.0
# Mean Reward 29.78676470588235
# Max reward so far:  137.0
# ==========================================
# Episode:  136
# Loss: -0.010755999945104122
# Reward:  175.0
# Mean Reward 30.846715328467152
# Max reward so far:  175.0
# ==========================================
# Episode:  137
# Loss: 0.004924951586872339
# Reward:  11.0
# Mean Reward 30.702898550724637
# Max reward so far:  175.0
# ==========================================
# Episode:  138
# Loss: -0.021165067330002785
# Reward:  39.0
# Mean Reward 30.762589928057555
# Max reward so far:  175.0
# ==========================================
# Episode:  139
# Loss: -0.014105649664998055
# Reward:  26.0
# Mean Reward 30.728571428571428
# Max reward so far:  175.0
# ==========================================
# Episode:  140
# Loss: -0.0028814305551350117
# Reward:  38.0
# Mean Reward 30.78014184397163
# Max reward so far:  175.0
# ==========================================
# Episode:  141
# Loss: 0.002692330861464143
# Reward:  20.0
# Mean Reward 30.704225352112676
# Max reward so far:  175.0
# ==========================================
# Episode:  142
# Loss: -0.08088074624538422
# Reward:  21.0
# Mean Reward 30.636363636363637
# Max reward so far:  175.0
# ==========================================
# Episode:  143
# Loss: -0.061595939099788666
# Reward:  53.0
# Mean Reward 30.791666666666668
# Max reward so far:  175.0
# ==========================================
# Episode:  144
# Loss: -0.0014364640228450298
# Reward:  13.0
# Mean Reward 30.66896551724138
# Max reward so far:  175.0
# ==========================================
# Episode:  145
# Loss: -0.00228692009113729
# Reward:  29.0
# Mean Reward 30.65753424657534
# Max reward so far:  175.0
# ==========================================
# Episode:  146
# Loss: 0.0010691100033000112
# Reward:  27.0
# Mean Reward 30.632653061224488
# Max reward so far:  175.0
# ==========================================
# Episode:  147
# Loss: 0.0051607778295874596
# Reward:  53.0
# Mean Reward 30.783783783783782
# Max reward so far:  175.0
# ==========================================
# Episode:  148
# Loss: -0.01151507068425417
# Reward:  43.0
# Mean Reward 30.86577181208054
# Max reward so far:  175.0
# ==========================================
# Episode:  149
# Loss: -0.019064895808696747
# Reward:  35.0
# Mean Reward 30.893333333333334
# Max reward so far:  175.0
# ==========================================
# Episode:  150
# Loss: -0.012388774193823338
# Reward:  33.0
# Mean Reward 30.90728476821192
# Max reward so far:  175.0
# ==========================================
# Episode:  151
# Loss: 0.004065647255629301
# Reward:  18.0
# Mean Reward 30.82236842105263
# Max reward so far:  175.0
# ==========================================
# Episode:  152
# Loss: -0.013857374899089336
# Reward:  34.0
# Mean Reward 30.84313725490196
# Max reward so far:  175.0
# ==========================================
# Episode:  153
# Loss: -0.02028559520840645
# Reward:  23.0
# Mean Reward 30.792207792207794
# Max reward so far:  175.0
# ==========================================
# Episode:  154
# Loss: -0.019619697704911232
# Reward:  77.0
# Mean Reward 31.09032258064516
# Max reward so far:  175.0
# ==========================================
# Episode:  155
# Loss: -0.008550806902348995
# Reward:  38.0
# Mean Reward 31.134615384615383
# Max reward so far:  175.0
# ==========================================
# Episode:  156
# Loss: -0.017049577087163925
# Reward:  27.0
# Mean Reward 31.10828025477707
# Max reward so far:  175.0
# ==========================================
# Episode:  157
# Loss: -0.04320378601551056
# Reward:  19.0
# Mean Reward 31.031645569620252
# Max reward so far:  175.0
# ==========================================
# Episode:  158
# Loss: -0.001049844897352159
# Reward:  37.0
# Mean Reward 31.069182389937108
# Max reward so far:  175.0
# ==========================================
# Episode:  159
# Loss: -0.0004945687251165509
# Reward:  11.0
# Mean Reward 30.94375
# Max reward so far:  175.0
# ==========================================
# Episode:  160
# Loss: -0.009265151806175709
# Reward:  27.0
# Mean Reward 30.919254658385093
# Max reward so far:  175.0
# ==========================================
# Episode:  161
# Loss: -0.006404108367860317
# Reward:  42.0
# Mean Reward 30.987654320987655
# Max reward so far:  175.0
# ==========================================
# Episode:  162
# Loss: -0.014610989019274712
# Reward:  51.0
# Mean Reward 31.11042944785276
# Max reward so far:  175.0
# ==========================================
# Episode:  163
# Loss: -0.0050132437609136105
# Reward:  20.0
# Mean Reward 31.04268292682927
# Max reward so far:  175.0
# ==========================================
# Episode:  164
# Loss: -0.02381240762770176
# Reward:  19.0
# Mean Reward 30.96969696969697
# Max reward so far:  175.0
# ==========================================
# Episode:  165
# Loss: -0.0541243813931942
# Reward:  97.0
# Mean Reward 31.367469879518072
# Max reward so far:  175.0
# ==========================================
# Episode:  166
# Loss: -0.000252839206950739
# Reward:  59.0
# Mean Reward 31.53293413173653
# Max reward so far:  175.0
# ==========================================
# Episode:  167
# Loss: -0.011726130731403828
# Reward:  17.0
# Mean Reward 31.446428571428573
# Max reward so far:  175.0
# ==========================================
# Episode:  168
# Loss: -0.029148248955607414
# Reward:  60.0
# Mean Reward 31.615384615384617
# Max reward so far:  175.0
# ==========================================
# Episode:  169
# Loss: -0.0106104277074337
# Reward:  85.0
# Mean Reward 31.929411764705883
# Max reward so far:  175.0
# ==========================================
# Episode:  170
# Loss: -0.0013521832879632711
# Reward:  25.0
# Mean Reward 31.88888888888889
# Max reward so far:  175.0
# ==========================================
# Episode:  171
# Loss: -0.06617569923400879
# Reward:  98.0
# Mean Reward 32.27325581395349
# Max reward so far:  175.0
# ==========================================
# Episode:  172
# Loss: -0.009952486492693424
# Reward:  46.0
# Mean Reward 32.35260115606936
# Max reward so far:  175.0
# ==========================================
# Episode:  173
# Loss: -0.021930063143372536
# Reward:  37.0
# Mean Reward 32.37931034482759
# Max reward so far:  175.0
# ==========================================
# Episode:  174
# Loss: -0.032818976789712906
# Reward:  28.0
# Mean Reward 32.354285714285716
# Max reward so far:  175.0
# ==========================================
# Episode:  175
# Loss: 0.021002139896154404
# Reward:  41.0
# Mean Reward 32.40340909090909
# Max reward so far:  175.0
# ==========================================
# Episode:  176
# Loss: -0.010033699683845043
# Reward:  65.0
# Mean Reward 32.58757062146893
# Max reward so far:  175.0
# ==========================================
# Episode:  177
# Loss: -0.01905211992561817
# Reward:  61.0
# Mean Reward 32.747191011235955
# Max reward so far:  175.0
# ==========================================
# Episode:  178
# Loss: -0.027855176478624344
# Reward:  102.0
# Mean Reward 33.134078212290504
# Max reward so far:  175.0
# ==========================================
# Episode:  179
# Loss: -0.03260258212685585
# Reward:  40.0
# Mean Reward 33.172222222222224
# Max reward so far:  175.0
# ==========================================
# Episode:  180
# Loss: -0.04914619028568268
# Reward:  41.0
# Mean Reward 33.21546961325967
# Max reward so far:  175.0
# ==========================================
# Episode:  181
# Loss: -0.04929233342409134
# Reward:  49.0
# Mean Reward 33.3021978021978
# Max reward so far:  175.0
# ==========================================
# Episode:  182
# Loss: -0.028782619163393974
# Reward:  87.0
# Mean Reward 33.595628415300546
# Max reward so far:  175.0
# ==========================================
# Episode:  183
# Loss: -0.006682975683361292
# Reward:  26.0
# Mean Reward 33.55434782608695
# Max reward so far:  175.0
# ==========================================
# Episode:  184
# Loss: 0.011814272962510586
# Reward:  206.0
# Mean Reward 34.486486486486484
# Max reward so far:  206.0
# ==========================================
# Episode:  185
# Loss: -0.00764841353520751
# Reward:  96.0
# Mean Reward 34.81720430107527
# Max reward so far:  206.0
# ==========================================
# Episode:  186
# Loss: -0.03365877643227577
# Reward:  202.0
# Mean Reward 35.711229946524064
# Max reward so far:  206.0
# ==========================================
# Episode:  187
# Loss: -0.010854770429432392
# Reward:  55.0
# Mean Reward 35.81382978723404
# Max reward so far:  206.0
# ==========================================
# Episode:  188
# Loss: -0.02617546357214451
# Reward:  49.0
# Mean Reward 35.883597883597886
# Max reward so far:  206.0
# ==========================================
# Episode:  189
# Loss: 0.007020854391157627
# Reward:  297.0
# Mean Reward 37.257894736842104
# Max reward so far:  297.0
# ==========================================
# Episode:  190
# Loss: -0.0014314507134258747
# Reward:  104.0
# Mean Reward 37.60732984293194
# Max reward so far:  297.0
# ==========================================
# Episode:  191
# Loss: -0.02379293367266655
# Reward:  155.0
# Mean Reward 38.21875
# Max reward so far:  297.0
# ==========================================
# Episode:  192
# Loss: -0.027584346011281013
# Reward:  21.0
# Mean Reward 38.129533678756474
# Max reward so far:  297.0
# ==========================================
# Episode:  193
# Loss: 0.003349681617692113
# Reward:  214.0
# Mean Reward 39.0360824742268
# Max reward so far:  297.0
# ==========================================
# Episode:  194
# Loss: 0.003166316542774439
# Reward:  108.0
# Mean Reward 39.38974358974359
# Max reward so far:  297.0
# ==========================================
# Episode:  195
# Loss: -0.01681211218237877
# Reward:  23.0
# Mean Reward 39.30612244897959
# Max reward so far:  297.0
# ==========================================
# Episode:  196
# Loss: 0.007294227369129658
# Reward:  23.0
# Mean Reward 39.223350253807105
# Max reward so far:  297.0
# ==========================================
# Episode:  197
# Loss: -0.13964837789535522
# Reward:  111.0
# Mean Reward 39.58585858585859
# Max reward so far:  297.0
# ==========================================
# Episode:  198
# Loss: -0.0025761895813047886
# Reward:  157.0
# Mean Reward 40.175879396984925
# Max reward so far:  297.0
# ==========================================
# Episode:  199
# Loss: -0.00834668893367052
# Reward:  151.0
# Mean Reward 40.73
# Max reward so far:  297.0
# ==========================================
# Episode:  200
# Loss: -0.01735636405646801
# Reward:  210.0
# Mean Reward 41.57213930348259
# Max reward so far:  297.0
# ==========================================
# Episode:  201
# Loss: -0.0038235276006162167
# Reward:  112.0
# Mean Reward 41.92079207920792
# Max reward so far:  297.0
# ==========================================
# Episode:  202
# Loss: -0.04623057320713997
# Reward:  205.0
# Mean Reward 42.724137931034484
# Max reward so far:  297.0
# ==========================================
# Episode:  203
# Loss: -0.013852624222636223
# Reward:  115.0
# Mean Reward 43.07843137254902
# Max reward so far:  297.0
# ==========================================
# Episode:  204
# Loss: -0.004460860509425402
# Reward:  49.0
# Mean Reward 43.107317073170734
# Max reward so far:  297.0
# ==========================================
# Episode:  205
# Loss: -0.017254719510674477
# Reward:  29.0
# Mean Reward 43.03883495145631
# Max reward so far:  297.0
# ==========================================
# Episode:  206
# Loss: -0.016660170629620552
# Reward:  170.0
# Mean Reward 43.65217391304348
# Max reward so far:  297.0
# ==========================================
# Episode:  207
# Loss: -0.012576515786349773
# Reward:  247.0
# Mean Reward 44.62980769230769
# Max reward so far:  297.0
# ==========================================
# Episode:  208
# Loss: 0.00015208692639134824
# Reward:  219.0
# Mean Reward 45.464114832535884
# Max reward so far:  297.0
# ==========================================
# Episode:  209
# Loss: -0.025694577023386955
# Reward:  218.0
# Mean Reward 46.285714285714285
# Max reward so far:  297.0
# ==========================================
# Episode:  210
# Loss: -0.010953997261822224
# Reward:  188.0
# Mean Reward 46.95734597156398
# Max reward so far:  297.0
# ==========================================
# Episode:  211
# Loss: -0.004597166087478399
# Reward:  250.0
# Mean Reward 47.91509433962264
# Max reward so far:  297.0
# ==========================================
# Episode:  212
# Loss: -0.002001225482672453
# Reward:  144.0
# Mean Reward 48.36619718309859
# Max reward so far:  297.0
# ==========================================
# Episode:  213
# Loss: -0.01382735650986433
# Reward:  215.0
# Mean Reward 49.14485981308411
# Max reward so far:  297.0
# ==========================================
# Episode:  214
# Loss: -0.0023742264602333307
# Reward:  162.0
# Mean Reward 49.669767441860465
# Max reward so far:  297.0
# ==========================================
# Episode:  215
# Loss: 0.002561343600973487
# Reward:  128.0
# Mean Reward 50.032407407407405
# Max reward so far:  297.0
# ==========================================
# Episode:  216
# Loss: -0.008980100043118
# Reward:  70.0
# Mean Reward 50.12442396313364
# Max reward so far:  297.0
# ==========================================
# Episode:  217
# Loss: -0.041983652859926224
# Reward:  206.0
# Mean Reward 50.8394495412844
# Max reward so far:  297.0
# ==========================================
# Episode:  218
# Loss: -0.006728381849825382
# Reward:  138.0
# Mean Reward 51.23744292237443
# Max reward so far:  297.0
# ==========================================
# Episode:  219
# Loss: -0.0340118408203125
# Reward:  204.0
# Mean Reward 51.93181818181818
# Max reward so far:  297.0
# ==========================================
# Episode:  220
# Loss: 0.008419244550168514
# Reward:  103.0
# Mean Reward 52.16289592760181
# Max reward so far:  297.0
# ==========================================
# Episode:  221
# Loss: 0.009688725695014
# Reward:  150.0
# Mean Reward 52.6036036036036
# Max reward so far:  297.0
# ==========================================
# Episode:  222
# Loss: 0.00116332049947232
# Reward:  141.0
# Mean Reward 53.0
# Max reward so far:  297.0
# ==========================================
# Episode:  223
# Loss: 0.0009505862835794687
# Reward:  130.0
# Mean Reward 53.34375
# Max reward so far:  297.0
# ==========================================
# Episode:  224
# Loss: -0.005548620130866766
# Reward:  172.0
# Mean Reward 53.87111111111111
# Max reward so far:  297.0
# ==========================================
# Episode:  225
# Loss: -0.03157515823841095
# Reward:  27.0
# Mean Reward 53.75221238938053
# Max reward so far:  297.0
# ==========================================
# Episode:  226
# Loss: -0.08197806775569916
# Reward:  194.0
# Mean Reward 54.370044052863435
# Max reward so far:  297.0
# ==========================================
# Episode:  227
# Loss: 0.004935957491397858
# Reward:  33.0
# Mean Reward 54.276315789473685
# Max reward so far:  297.0
# ==========================================
# Episode:  228
# Loss: -0.07000289857387543
# Reward:  130.0
# Mean Reward 54.60698689956332
# Max reward so far:  297.0
# ==========================================
# Episode:  229
# Loss: -0.011256309226155281
# Reward:  128.0
# Mean Reward 54.926086956521736
# Max reward so far:  297.0
# ==========================================
# Episode:  230
# Loss: -0.007489695679396391
# Reward:  116.0
# Mean Reward 55.19047619047619
# Max reward so far:  297.0
# ==========================================
# Episode:  231
# Loss: -0.03507419675588608
# Reward:  234.0
# Mean Reward 55.96120689655172
# Max reward so far:  297.0
# ==========================================
# Episode:  232
# Loss: -0.0031164914835244417
# Reward:  183.0
# Mean Reward 56.506437768240346
# Max reward so far:  297.0
# ==========================================
# Episode:  233
# Loss: -0.001517847878858447
# Reward:  208.0
# Mean Reward 57.15384615384615
# Max reward so far:  297.0
# ==========================================
# Episode:  234
# Loss: -0.006772945169359446
# Reward:  180.0
# Mean Reward 57.67659574468085
# Max reward so far:  297.0
# ==========================================
# Episode:  235
# Loss: -0.009777405299246311
# Reward:  175.0
# Mean Reward 58.17372881355932
# Max reward so far:  297.0
# ==========================================
# Episode:  236
# Loss: -0.009349293075501919
# Reward:  230.0
# Mean Reward 58.89873417721519
# Max reward so far:  297.0
# ==========================================
# Episode:  237
# Loss: -0.005867521278560162
# Reward:  191.0
# Mean Reward 59.45378151260504
# Max reward so far:  297.0
# ==========================================
# Episode:  238
# Loss: -0.011196086183190346
# Reward:  91.0
# Mean Reward 59.58577405857741
# Max reward so far:  297.0
# ==========================================
# Episode:  239
# Loss: -0.04794616624712944
# Reward:  28.0
# Mean Reward 59.454166666666666
# Max reward so far:  297.0
# ==========================================
# Episode:  240
# Loss: -0.001729481969960034
# Reward:  191.0
# Mean Reward 60.0
# Max reward so far:  297.0
# ==========================================
# Episode:  241
# Loss: -0.03205854445695877
# Reward:  395.0
# Mean Reward 61.38429752066116
# Max reward so far:  395.0
# ==========================================
# Episode:  242
# Loss: -0.007417646702378988
# Reward:  212.0
# Mean Reward 62.00411522633745
# Max reward so far:  395.0
# ==========================================
# Episode:  243
# Loss: -0.006529617588967085
# Reward:  378.0
# Mean Reward 63.299180327868854
# Max reward so far:  395.0
# ==========================================
# Episode:  244
# Loss: -0.006759402807801962
# Reward:  182.0
# Mean Reward 63.78367346938776
# Max reward so far:  395.0
# ==========================================
# Episode:  245
# Loss: -0.012856044806540012
# Reward:  136.0
# Mean Reward 64.07723577235772
# Max reward so far:  395.0
# ==========================================
# Episode:  246
# Loss: -0.017821209505200386
# Reward:  315.0
# Mean Reward 65.09311740890688
# Max reward so far:  395.0
# ==========================================
# Episode:  247
# Loss: -0.023906810209155083
# Reward:  174.0
# Mean Reward 65.53225806451613
# Max reward so far:  395.0
# ==========================================
# Episode:  248
# Loss: 0.0017515209037810564
# Reward:  209.0
# Mean Reward 66.10843373493977
# Max reward so far:  395.0
# ==========================================
# Episode:  249
# Loss: -0.00867086835205555
# Reward:  235.0
# Mean Reward 66.784
# Max reward so far:  395.0
# ==========================================
# Episode:  250
# Loss: -0.04020078107714653
# Reward:  240.0
# Mean Reward 67.47410358565737
# Max reward so far:  395.0
# ==========================================
# Episode:  251
# Loss: 0.00411278335377574
# Reward:  465.0
# Mean Reward 69.0515873015873
# Max reward so far:  465.0
# ==========================================
# Episode:  252
# Loss: 0.002410580636933446
# Reward:  167.0
# Mean Reward 69.43873517786561
# Max reward so far:  465.0
# ==========================================
# Episode:  253
# Loss: -0.016840001568198204
# Reward:  165.0
# Mean Reward 69.81496062992126
# Max reward so far:  465.0
# ==========================================
# Episode:  254
# Loss: -0.004967543762177229
# Reward:  121.0
# Mean Reward 70.0156862745098
# Max reward so far:  465.0
# ==========================================
# Episode:  255
# Loss: 0.015494470484554768
# Reward:  434.0
# Mean Reward 71.4375
# Max reward so far:  465.0
# ==========================================
# Episode:  256
# Loss: -0.00776691036298871
# Reward:  137.0
# Mean Reward 71.69260700389106
# Max reward so far:  465.0
# ==========================================
# Episode:  257
# Loss: -0.016353419050574303
# Reward:  163.0
# Mean Reward 72.04651162790698
# Max reward so far:  465.0
# ==========================================
# Episode:  258
# Loss: -0.0006196513422764838
# Reward:  409.0
# Mean Reward 73.34749034749035
# Max reward so far:  465.0
# ==========================================
# Episode:  259
# Loss: -0.0024112528190016747
# Reward:  176.0
# Mean Reward 73.74230769230769
# Max reward so far:  465.0
# ==========================================
# Episode:  260
# Loss: 0.001667266245931387
# Reward:  180.0
# Mean Reward 74.14942528735632
# Max reward so far:  465.0
# ==========================================
# Episode:  261
# Loss: -0.007453026250004768
# Reward:  336.0
# Mean Reward 75.14885496183206
# Max reward so far:  465.0
# ==========================================
# Episode:  262
# Loss: -0.00017178041161969304
# Reward:  251.0
# Mean Reward 75.81749049429658
# Max reward so far:  465.0
# ==========================================
# Episode:  263
# Loss: -0.007944737561047077
# Reward:  45.0
# Mean Reward 75.70075757575758
# Max reward so far:  465.0
# ==========================================
# Episode:  264
# Loss: -0.05209212377667427
# Reward:  156.0
# Mean Reward 76.00377358490566
# Max reward so far:  465.0
# ==========================================
# Episode:  265
# Loss: -0.01711583137512207
# Reward:  490.0
# Mean Reward 77.56015037593986
# Max reward so far:  490.0
# ==========================================
# Episode:  266
# Loss: -0.003964175470173359
# Reward:  411.0
# Mean Reward 78.80898876404494
# Max reward so far:  490.0
# ==========================================
# Episode:  267
# Loss: -0.02485119365155697
# Reward:  143.0
# Mean Reward 79.04850746268657
# Max reward so far:  490.0
# ==========================================
# Episode:  268
# Loss: -0.007228327915072441
# Reward:  242.0
# Mean Reward 79.6542750929368
# Max reward so far:  490.0
# ==========================================
# Episode:  269
# Loss: -0.040021855384111404
# Reward:  42.0
# Mean Reward 79.51481481481481
# Max reward so far:  490.0
# ==========================================
# Episode:  270
# Loss: -0.031215960159897804
# Reward:  77.0
# Mean Reward 79.50553505535055
# Max reward so far:  490.0
# ==========================================
# Episode:  271
# Loss: -0.06723910570144653
# Reward:  128.0
# Mean Reward 79.68382352941177
# Max reward so far:  490.0
# ==========================================
# Episode:  272
# Loss: -0.010962667874991894
# Reward:  151.0
# Mean Reward 79.94505494505495
# Max reward so far:  490.0
# ==========================================
# Episode:  273
# Loss: -0.012699248269200325
# Reward:  204.0
# Mean Reward 80.39781021897811
# Max reward so far:  490.0
# ==========================================
# Episode:  274
# Loss: -0.015775982290506363
# Reward:  102.0
# Mean Reward 80.47636363636363
# Max reward so far:  490.0
# ==========================================
# Episode:  275
# Loss: -0.004304493311792612
# Reward:  265.0
# Mean Reward 81.14492753623189
# Max reward so far:  490.0
# ==========================================
# Episode:  276
# Loss: -0.01255462784320116
# Reward:  275.0
# Mean Reward 81.84476534296029
# Max reward so far:  490.0
# ==========================================
# Episode:  277
# Loss: -0.006930183619260788
# Reward:  383.0
# Mean Reward 82.92805755395683
# Max reward so far:  490.0
# ==========================================
# Episode:  278
# Loss: -0.02967851422727108
# Reward:  235.0
# Mean Reward 83.47311827956989
# Max reward so far:  490.0
# ==========================================
# Episode:  279
# Loss: 0.001090522506274283
# Reward:  452.0
# Mean Reward 84.78928571428571
# Max reward so far:  490.0
# ==========================================
# Episode:  280
# Loss: -0.00801617931574583
# Reward:  130.0
# Mean Reward 84.95017793594306
# Max reward so far:  490.0
# ==========================================
# Episode:  281
# Loss: 0.013517796993255615
# Reward:  277.0
# Mean Reward 85.63120567375887
# Max reward so far:  490.0
# ==========================================
# Episode:  282
# Loss: -0.029111115261912346
# Reward:  251.0
# Mean Reward 86.2155477031802
# Max reward so far:  490.0
# ==========================================
# Episode:  283
# Loss: -0.004127329681068659
# Reward:  183.0
# Mean Reward 86.55633802816901
# Max reward so far:  490.0
# ==========================================
# Episode:  284
# Loss: -0.01815207116305828
# Reward:  688.0
# Mean Reward 88.66666666666667
# Max reward so far:  688.0
# ==========================================
# Episode:  285
# Loss: -0.006575309205800295
# Reward:  287.0
# Mean Reward 89.36013986013987
# Max reward so far:  688.0
# ==========================================
# Episode:  286
# Loss: -0.021895358338952065
# Reward:  683.0
# Mean Reward 91.42857142857143
# Max reward so far:  688.0
# ==========================================
# Episode:  287
# Loss: 0.004495402332395315
# Reward:  899.0
# Mean Reward 94.23263888888889
# Max reward so far:  899.0
# ==========================================
# Episode:  288
# Loss: -0.0013029241235926747
# Reward:  196.0
# Mean Reward 94.58477508650519
# Max reward so far:  899.0
# ==========================================
# Episode:  289
# Loss: -0.0213293619453907
# Reward:  1147.0
# Mean Reward 98.21379310344828
# Max reward so far:  1147.0
# ==========================================
# Episode:  290
# Loss: -0.0131838982924819
# Reward:  330.0
# Mean Reward 99.01030927835052
# Max reward so far:  1147.0
# ==========================================
# Episode:  291
# Loss: -0.01848803088068962
# Reward:  214.0
# Mean Reward 99.4041095890411
# Max reward so far:  1147.0
# ==========================================
# Episode:  292
# Loss: -0.02041778154671192
# Reward:  365.0
# Mean Reward 100.31058020477816
# Max reward so far:  1147.0
# ==========================================
# Episode:  293
# Loss: -0.01682078093290329
# Reward:  305.0
# Mean Reward 101.00680272108843
# Max reward so far:  1147.0
# ==========================================
# Episode:  294
# Loss: -0.015169705264270306
# Reward:  336.0
# Mean Reward 101.80338983050848
# Max reward so far:  1147.0
# ==========================================
# Episode:  295
# Loss: 0.0005714449798688293
# Reward:  256.0
# Mean Reward 102.32432432432432
# Max reward so far:  1147.0
# ==========================================
# Episode:  296
# Loss: -0.02912079356610775
# Reward:  1139.0
# Mean Reward 105.81481481481481
# Max reward so far:  1147.0
# ==========================================
# Episode:  297
# Loss: -0.0033330603037029505
# Reward:  453.0
# Mean Reward 106.97986577181209
# Max reward so far:  1147.0
# ==========================================
# Episode:  298
# Loss: -0.02191256359219551
# Reward:  404.0
# Mean Reward 107.97324414715719
# Max reward so far:  1147.0
# ==========================================
# Episode:  299
# Loss: -0.008437339216470718
# Reward:  494.0
# Mean Reward 109.26
# Max reward so far:  1147.0
# ==========================================
# Episode:  300
# Loss: -0.00993629451841116
# Reward:  695.0
# Mean Reward 111.20598006644518
# Max reward so far:  1147.0
# ==========================================
# Episode:  301
# Loss: -0.018933193758130074
# Reward:  338.0
# Mean Reward 111.95695364238411
# Max reward so far:  1147.0
# ==========================================
# Episode:  302
# Loss: -0.021199647337198257
# Reward:  402.0
# Mean Reward 112.91419141914191
# Max reward so far:  1147.0
# ==========================================
# Episode:  303
# Loss: -0.008969389833509922
# Reward:  280.0
# Mean Reward 113.46381578947368
# Max reward so far:  1147.0
# ==========================================
# Episode:  304
# Loss: -0.014045956544578075
# Reward:  589.0
# Mean Reward 115.02295081967213
# Max reward so far:  1147.0
# ==========================================
# Episode:  305
# Loss: -0.0012325163697823882
# Reward:  2716.0
# Mean Reward 123.52287581699346
# Max reward so far:  2716.0
# ==========================================
# Episode:  306
# Loss: 0.004987598862498999
# Reward:  56.0
# Mean Reward 123.3029315960912
# Max reward so far:  2716.0
# ==========================================
# Episode:  307
# Loss: -0.051933202892541885
# Reward:  458.0
# Mean Reward 124.3896103896104
# Max reward so far:  2716.0
# ==========================================
# Episode:  308
# Loss: -0.0130911348387599
# Reward:  1235.0
# Mean Reward 127.98381877022653
# Max reward so far:  2716.0
# ==========================================
# Episode:  309
# Loss: 0.0009527168003842235
# Reward:  617.0
# Mean Reward 129.56129032258065
# Max reward so far:  2716.0
# ==========================================
# Episode:  310
# Loss: -0.0035907260607928038
# Reward:  946.0
# Mean Reward 132.18649517684887
# Max reward so far:  2716.0
# ==========================================
# Episode:  311
# Loss: 0.0019429178209975362
# Reward:  1224.0
# Mean Reward 135.68589743589743
# Max reward so far:  2716.0
# ==========================================
# Episode:  312
# Loss: 0.0018209846457466483
# Reward:  655.0
# ...
# Max reward so far:  26371.0
# ==========================================
# Episode:  936
# Loss: -0.07368646562099457
# Reward:  253.0
# Mean Reward 366.22945570971183
# Max reward so far:  26371.0
# ==========================================
# Episode:  937
# Loss: -0.058431487530469894
# Reward:  236.0
# Mean Reward 366.090618336887
# Max reward so far:  26371.0
# ==========================================
# Episode:  938
# Loss: -0.05956282839179039
# Reward:  267.0
# Mean Reward 365.98509052183175
# Max reward so far:  26371.0
# ==========================================
# Episode:  939
# Loss: -0.05801897868514061
# Reward:  233.0
# Mean Reward 365.8436170212766
# Max reward so far:  26371.0
# ==========================================
# Episode:  940
# Loss: -0.06689683347940445
# Reward:  215.0
# Mean Reward 365.68331562167907
# Max reward so far:  26371.0
# ==========================================
# Episode:  941
# Loss: -0.081279456615448
# Reward:  228.0
# Mean Reward 365.5371549893843
# Max reward so far:  26371.0
# ==========================================
# Episode:  942
# Loss: -0.07085911184549332
# Reward:  222.0
# Mean Reward 365.38494167550374
# Max reward so far:  26371.0
# ==========================================
# Episode:  943
# Loss: -0.06232942268252373
# Reward:  315.0
# Mean Reward 365.33156779661016
# Max reward so far:  26371.0
# ==========================================
# Episode:  944
# Loss: -0.051547057926654816
# Reward:  193.0
# Mean Reward 365.14920634920634
# Max reward so far:  26371.0
# ==========================================
# Episode:  945
# Loss: -0.062374331057071686
# Reward:  197.0
# Mean Reward 364.9714587737844
# Max reward so far:  26371.0
# ==========================================
# Episode:  946
# Loss: -0.07815716415643692
# Reward:  242.0
# Mean Reward 364.8416050686378
# Max reward so far:  26371.0
# ==========================================
# Episode:  947
# Loss: -0.06171185523271561
# Reward:  158.0
# Mean Reward 364.623417721519
# Max reward so far:  26371.0
# ==========================================
# Episode:  948
# Loss: -0.07187782973051071
# Reward:  189.0
# Mean Reward 364.43835616438355
# Max reward so far:  26371.0
# ==========================================
# Episode:  949
# Loss: -0.07884238660335541
# Reward:  175.0
# Mean Reward 364.23894736842107
# Max reward so far:  26371.0
# ==========================================
# Episode:  950
# Loss: -0.0690200999379158
# Reward:  162.0
# Mean Reward 364.0262881177708
# Max reward so far:  26371.0
# ==========================================
# Episode:  951
# Loss: -0.09259679913520813
# Reward:  173.0
# Mean Reward 363.82563025210084
# Max reward so far:  26371.0
# ==========================================
# Episode:  952
# Loss: -0.08713764697313309
# Reward:  165.0
# Mean Reward 363.61699895068205
# Max reward so far:  26371.0
# ==========================================
# Episode:  953
# Loss: -0.09879106283187866
# Reward:  136.0
# Mean Reward 363.3784067085954
# Max reward so far:  26371.0
# ==========================================
# Episode:  954
# Loss: -0.08227451890707016
# Reward:  197.0
# Mean Reward 363.2041884816754
# Max reward so far:  26371.0
# ==========================================
# Episode:  955
# Loss: -0.0840313732624054
# Reward:  178.0
# Mean Reward 363.010460251046
# Max reward so far:  26371.0
# ==========================================
# Episode:  956
# Loss: -0.09292800724506378
# Reward:  150.0
# Mean Reward 362.7878787878788
# Max reward so far:  26371.0
# ==========================================
# Episode:  957
# Loss: -0.08712001144886017
# Reward:  187.0
# Mean Reward 362.6043841336117
# Max reward so far:  26371.0
# ==========================================
# Episode:  958
# Loss: -0.07919954508543015
# Reward:  242.0
# Mean Reward 362.4786235662148
# Max reward so far:  26371.0
# ==========================================
# Episode:  959
# Loss: -0.06264718621969223
# Reward:  178.0
# Mean Reward 362.2864583333333
# Max reward so far:  26371.0
# ==========================================
# Episode:  960
# Loss: -0.06829984486103058
# Reward:  169.0
# Mean Reward 362.0853277835588
# Max reward so far:  26371.0
# ==========================================
# Episode:  961
# Loss: -0.06273490190505981
# Reward:  186.0
# Mean Reward 361.9022869022869
# Max reward so far:  26371.0
# ==========================================
# Episode:  962
# Loss: -0.08105330169200897
# Reward:  166.0
# Mean Reward 361.69885773624094
# Max reward so far:  26371.0
# ==========================================
# Episode:  963
# Loss: -0.09409768879413605
# Reward:  180.0
# Mean Reward 361.5103734439834
# Max reward so far:  26371.0
# ==========================================
# Episode:  964
# Loss: -0.07550691813230515
# Reward:  159.0
# Mean Reward 361.30051813471505
# Max reward so far:  26371.0
# ==========================================
# Episode:  965
# Loss: -0.0999687910079956
# Reward:  143.0
# Mean Reward 361.0745341614907
# Max reward so far:  26371.0
# ==========================================
# Episode:  966
# Loss: -0.0562555268406868
# Reward:  141.0
# Mean Reward 360.846949327818
# Max reward so far:  26371.0
# ==========================================
# Episode:  967
# Loss: -0.07218990474939346
# Reward:  202.0
# Mean Reward 360.68285123966945
# Max reward so far:  26371.0
# ==========================================
# Episode:  968
# Loss: -0.08642984181642532
# Reward:  131.0
# Mean Reward 360.44582043343655
# Max reward so far:  26371.0
# ==========================================
# Episode:  969
# Loss: -0.07261215150356293
# Reward:  141.0
# Mean Reward 360.21958762886595
# Max reward so far:  26371.0
# ==========================================
# Episode:  970
# Loss: -0.08167921751737595
# Reward:  177.0
# Mean Reward 360.03089598352216
# Max reward so far:  26371.0
# ==========================================
# Episode:  971
# Loss: -0.08490487188100815
# Reward:  183.0
# Mean Reward 359.8487654320988
# Max reward so far:  26371.0
# ==========================================
# Episode:  972
# Loss: -0.07920881360769272
# Reward:  145.0
# Mean Reward 359.6279547790339
# Max reward so far:  26371.0
# ==========================================
# Episode:  973
# Loss: -0.09074068814516068
# Reward:  188.0
# Mean Reward 359.4517453798768
# Max reward so far:  26371.0
# ==========================================
# Episode:  974
# Loss: -0.08419723808765411
# Reward:  159.0
# Mean Reward 359.24615384615385
# Max reward so far:  26371.0
# ==========================================
# Episode:  975
# Loss: -0.10703631490468979
# Reward:  235.0
# Mean Reward 359.1188524590164
# Max reward so far:  26371.0
# ==========================================
# Episode:  976
# Loss: -0.06103651598095894
# Reward:  216.0
# Mean Reward 358.9723643807574
# Max reward so far:  26371.0
# ==========================================
# Episode:  977
# Loss: -0.04407772794365883
# Reward:  178.0
# Mean Reward 358.7873210633947
# Max reward so far:  26371.0
# ==========================================
# Episode:  978
# Loss: -0.0795980915427208
# Reward:  201.0
# Mean Reward 358.62614913176714
# Max reward so far:  26371.0
# ==========================================
# Episode:  979
# Loss: -0.07273253053426743
# Reward:  177.0
# Mean Reward 358.44081632653064
# Max reward so far:  26371.0
# ==========================================
# Episode:  980
# Loss: -0.05729684606194496
# Reward:  164.0
# Mean Reward 358.2426095820591
# Max reward so far:  26371.0
# ==========================================
# Episode:  981
# Loss: -0.06979390233755112
# Reward:  156.0
# Mean Reward 358.0366598778004
# Max reward so far:  26371.0
# ==========================================
# Episode:  982
# Loss: -0.09379246085882187
# Reward:  201.0
# Mean Reward 357.8769074262462
# Max reward so far:  26371.0
# ==========================================
# Episode:  983
# Loss: -0.07544896006584167
# Reward:  175.0
# Mean Reward 357.6910569105691
# Max reward so far:  26371.0
# ==========================================
# Episode:  984
# Loss: -0.0858457088470459
# Reward:  154.0
# Mean Reward 357.4842639593909
# Max reward so far:  26371.0
# ==========================================
# Episode:  985
# Loss: -0.07475732266902924
# Reward:  172.0
# Mean Reward 357.2961460446247
# Max reward so far:  26371.0
# ==========================================
# Episode:  986
# Loss: -0.0985662117600441
# Reward:  137.0
# Mean Reward 357.0729483282675
# Max reward so far:  26371.0
# ==========================================
# Episode:  987
# Loss: -0.0909411832690239
# Reward:  145.0
# Mean Reward 356.8582995951417
# Max reward so far:  26371.0
# ==========================================
# Episode:  988
# Loss: -0.054287139326334
# Reward:  165.0
# Mean Reward 356.6643073811931
# Max reward so far:  26371.0
# ==========================================
# Episode:  989
# Loss: -0.08230869472026825
# Reward:  179.0
# Mean Reward 356.4848484848485
# Max reward so far:  26371.0
# ==========================================
# Episode:  990
# Loss: -0.05173937976360321
# Reward:  185.0
# Mean Reward 356.31180625630674
# Max reward so far:  26371.0
# ==========================================
# Episode:  991
# Loss: -0.09526041150093079
# Reward:  165.0
# Mean Reward 356.11895161290323
# Max reward so far:  26371.0
# ==========================================
# Episode:  992
# Loss: -0.09729424864053726
# Reward:  185.0
# Mean Reward 355.9466263846929
# Max reward so far:  26371.0
# ==========================================
# Episode:  993
# Loss: -0.09519769996404648
# Reward:  208.0
# Mean Reward 355.79778672032194
# Max reward so far:  26371.0
# ==========================================
# Episode:  994
# Loss: -0.06482623517513275
# Reward:  176.0
# Mean Reward 355.6170854271357
# Max reward so far:  26371.0
# ==========================================
# Episode:  995
# Loss: -0.08328539878129959
# Reward:  200.0
# Mean Reward 355.46084337349396
# Max reward so far:  26371.0
# ==========================================
# Episode:  996
# Loss: -0.08873609453439713
# Reward:  183.0
# Mean Reward 355.2878635907723
# Max reward so far:  26371.0
# ==========================================
# Episode:  997
# Loss: -0.08689823001623154
# Reward:  156.0
# Mean Reward 355.08817635270543
# Max reward so far:  26371.0
# ==========================================
# Episode:  998
# Loss: -0.06456014513969421
# Reward:  176.0
# Mean Reward 354.9089089089089
# Max reward so far:  26371.0
# ==========================================
# Episode:  999
# Loss: -0.07582220435142517
# Reward:  167.0
# Mean Reward 354.721
# Max reward so far:  26371.0
# ==========================================
# Episode:  1000
# Loss: -0.09077693521976471
# Reward:  174.0
# Mean Reward 354.54045954045955
# Max reward so far:  26371.0
# ==========================================
# Episode:  1001
# Loss: -0.06045662611722946
# Reward:  249.0
# Mean Reward 354.43512974051896
# Max reward so far:  26371.0
# ==========================================
# Episode:  1002
# Loss: -0.030135830864310265
# Reward:  221.0
# Mean Reward 354.3020937188435
# Max reward so far:  26371.0
# ==========================================
# Episode:  1003
# Loss: -0.04904603585600853
# Reward:  194.0
# Mean Reward 354.1424302788845
# Max reward so far:  26371.0
# ==========================================
# Episode:  1004
# Loss: -0.08230031281709671
# Reward:  322.0
# Mean Reward 354.11044776119405
# Max reward so far:  26371.0
# ==========================================
# Episode:  1005
# Loss: -0.0351545549929142
# Reward:  213.0
# Mean Reward 353.97017892644135
# Max reward so far:  26371.0
# ==========================================
# Episode:  1006
# Loss: -0.04563646763563156
# Reward:  205.0
# Mean Reward 353.82224428997023
# Max reward so far:  26371.0
# ==========================================
# Episode:  1007
# Loss: -0.05069531127810478
# Reward:  291.0
# Mean Reward 353.75992063492066
# Max reward so far:  26371.0
# ==========================================
# Episode:  1008
# Loss: -0.0173952579498291
# Reward:  207.0
# Mean Reward 353.61446977205156
# Max reward so far:  26371.0
# ==========================================
# Episode:  1009
# Loss: -0.08004917949438095
# Reward:  305.0
# Mean Reward 353.56633663366335
# Max reward so far:  26371.0
# ==========================================
# Episode:  1010
# Loss: -0.04445502534508705
# Reward:  241.0
# Mean Reward 353.4549950544016
# Max reward so far:  26371.0
# ==========================================
# Episode:  1011
# Loss: -0.05313540995121002
# Reward:  258.0
# Mean Reward 353.3606719367589
# Max reward so far:  26371.0
# ==========================================
# Episode:  1012
# Loss: -0.06372951716184616
# Reward:  327.0
# Mean Reward 353.33464955577494
# Max reward so far:  26371.0
# ==========================================
# Episode:  1013
# Loss: -0.04949615150690079
# Reward:  499.0
# Mean Reward 353.47830374753454
# Max reward so far:  26371.0
# ==========================================
# Episode:  1014
# Loss: -0.052364517003297806
# Reward:  460.0
# Mean Reward 353.5832512315271
# Max reward so far:  26371.0
# ==========================================
# Episode:  1015
# Loss: -0.028917420655488968
# Reward:  254.0
# Mean Reward 353.4852362204724
# Max reward so far:  26371.0
# ==========================================
# Episode:  1016
# Loss: -0.05538690835237503
# Reward:  545.0
# Mean Reward 353.67354965585054
# Max reward so far:  26371.0
# ==========================================
# Episode:  1017
# Loss: -0.011839261278510094
# Reward:  248.0
# Mean Reward 353.5697445972495
# Max reward so far:  26371.0
# ==========================================
# Episode:  1018
# Loss: -0.009252792224287987
# Reward:  281.0
# Mean Reward 353.49852796859665
# Max reward so far:  26371.0
# ==========================================
# Episode:  1019
# Loss: -0.05559300631284714
# Reward:  389.0
# Mean Reward 353.53333333333336
# Max reward so far:  26371.0
# ==========================================
# Episode:  1020
# Loss: -0.004683090839534998
# Reward:  303.0
# Mean Reward 353.48383937316356
# Max reward so far:  26371.0
# ==========================================
# Episode:  1021
# Loss: -0.04870959371328354
# Reward:  250.0
# Mean Reward 353.3825831702544
# Max reward so far:  26371.0
# ==========================================
# Episode:  1022
# Loss: -0.02841530367732048
# Reward:  188.0
# Mean Reward 353.2209188660802
# Max reward so far:  26371.0
# ==========================================
# Episode:  1023
# Loss: -0.07779958099126816
# Reward:  268.0
# Mean Reward 353.1376953125
# Max reward so far:  26371.0
# ==========================================
# Episode:  1024
# Loss: -0.07738585770130157
# Reward:  307.0
# Mean Reward 353.09268292682924
# Max reward so far:  26371.0
# ==========================================
# Episode:  1025
# Loss: -0.05118979513645172
# Reward:  376.0
# Mean Reward 353.11500974658867
# Max reward so far:  26371.0
# ==========================================
# Episode:  1026
# Loss: -0.0540560707449913
# Reward:  10855.0
# Mean Reward 363.3407984420643
# Max reward so far:  26371.0
# ==========================================
# Episode:  1027
# Loss: -0.010490866377949715
# Reward:  20315.0
# Mean Reward 382.7490272373541
# Max reward so far:  26371.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-30a21a0fa91b> in <module>()
#      11
#      12     while True:
# ---> 13         pi = nnet.predict(state.reshape([1,4]))
#      14 #         print(pi)
#      15         action = np.random.choice(range(pi.shape[1]), p=pi.ravel())
#
# <ipython-input-6-90c527736944> in predict(self, state)
#      44             state = Variable(state)
#      45         self.nnet.eval()
# ---> 46         x = self.nnet(state)
#      47         return torch.exp(x).data.cpu().numpy()
#      48
#
# ~\Anaconda3\envs\alphastone\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-6-90c527736944> in forward(self, x)
#       6         self.fc3 = nn.Linear(2, 2)
#       7     def forward(self, x):
# ----> 8         x = F.relu(self.fc1(x))
#       9         x = F.relu(self.fc2(x))
#      10         x = self.fc3(x)
#
# ~\Anaconda3\envs\alphastone\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#     617     if inplace:
#     618         return torch.relu_(input)
# --> 619     return torch.relu(input)
#     620
#     621
#
# KeyboardInterrupt:

# %% [markdown]
# input = torch.randn(3, 5, requires_grad=True)
# target = torch.empty(3, dtype=torch.long).random_(5)
# print(input.shape, target.shape)

# %%
for episode in range(5):
    state = env.reset()
    step = 0
    done = False
    total_rewards = 0
    print("*****************")
    print("Episode ", episode)
    
    while True:
        pi = nnet.predict(state)
        action = np.argmax(pi)
        new_state, reward, done, info = env.step(action)
        
        if done:
            print("Reward: ", reward)
            print("Info: ", info)
            break
        state = new_state
env.close()
# Out:
# *****************
# Episode  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ef049ac57784> in <module>()
#       8
#       9     while True:
# ---> 10         pi = nnet.predict(state)
#      11         action = np.argmax(pi)
#      12         new_state, reward, done, info = env.step(action)
#
# <ipython-input-6-90c527736944> in predict(self, state)
#      44             state = Variable(state)
#      45         self.nnet.eval()
# ---> 46         x = self.nnet(state)
#      47         return torch.exp(x).data.cpu().numpy()
#      48
#
# ~\Anaconda3\envs\alphastone\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-6-90c527736944> in forward(self, x)
#       7     def forward(self, x):
#       8         x = F.relu(self.fc1(x))
# ----> 9         x = F.relu(self.fc2(x))
#      10         x = self.fc3(x)
#      11         x = F.log_softmax(x, dim=-1)
#
# ~\Anaconda3\envs\alphastone\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~\Anaconda3\envs\alphastone\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def extra_repr(self):
#
# ~\Anaconda3\envs\alphastone\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#     994     output = input.matmul(weight.t())
#     995     if bias is not None:
# --> 996         output += bias
#     997     return output
#     998
#
# KeyboardInterrupt:

# %%
state = env.reset()
print(state)
